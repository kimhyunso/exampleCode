# %% [markdown]
# # Q1. chipotle 데이터를 로드해주세요.

# %%
import pandas as pd
chipotle_df = pd.read_csv('./chipotle/chipotle.tsv', sep='\t')
chipotle_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# # Q2. 'quantity'의 값이 3인 데이터를 추출한다.
# # 0부터 index를 재정렬한 후 상위 5개행만을 추출해보자.

# %%
chipotle_df[chipotle_df.quantity == 3].reset_index().head(5)
# Out:
#    index  order_id  quantity          item_name  \
# 0    409       178         3       Chicken Bowl
# 1    445       193         3               Bowl
# 2    689       284         3  Canned Soft Drink
# 3    818       338         3      Bottled Water
# 4    850       350         3  Canned Soft Drink
#
#                                   choice_description item_price
# 0  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $32.94
# 1  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 2                                        [Diet Coke]     $3.75
# 3                                                NaN     $3.27
# 4                                           [Sprite]     $3.75

# %% [markdown]
# # Q3 'quantity', 'item_name', 'item_price'로만 구성된 데이터 프레임을
# # new_df라고 정의해보자.

# %%
# new_df = chipotle_df[['quantity', 'item_name', 'item_price']]
# new_df

new_df = chipotle_df.iloc[:, 1:3]
new_df['item_price'] = chipotle_df.item_price
new_df
# Out:
#       quantity                              item_name item_price
# 0            1           Chips and Fresh Tomato Salsa     $2.39
# 1            1                                   Izze     $3.39
# 2            1                       Nantucket Nectar     $3.39
# 3            1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4            2                           Chicken Bowl    $16.98
# ...        ...                                    ...        ...
# 4617         1                          Steak Burrito    $11.75
# 4618         1                          Steak Burrito    $11.75
# 4619         1                     Chicken Salad Bowl    $11.25
# 4620         1                     Chicken Salad Bowl     $8.75
# 4621         1                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 3 columns]

# %% [markdown]
# # Q4 'item_name'이 'Chicken Burrito'인 데이터 프레임을 추출하고 인덱스를 초기화해보세요 ^^

# %%
chipotle_df[chipotle_df['item_name'] == 'Chicken Burrito'].reset_index()
# Out:
#      index  order_id  quantity        item_name  \
# 0       16         8         1  Chicken Burrito
# 1       17         9         1  Chicken Burrito
# 2       23        12         1  Chicken Burrito
# 3       29        15         1  Chicken Burrito
# 4       45        21         1  Chicken Burrito
# ..     ...       ...       ...              ...
# 548   4556      1811         1  Chicken Burrito
# 549   4558      1812         1  Chicken Burrito
# 550   4559      1812         1  Chicken Burrito
# 551   4566      1816         1  Chicken Burrito
# 552   4569      1817         1  Chicken Burrito
#
#                                     choice_description item_price
# 0    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 1    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 2    [[Tomatillo-Green Chili Salsa (Medium), Tomati...    $10.98
# 3    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# ...

# %% [markdown]
# # Q5 'item_name'중 'Burrito'가 포함된 경우의 데이터를 호출해주세요. 난이도-상

# %%
chipotle_df[chipotle_df['item_name'].str.contains('Burrito')].item_name.value_counts()
chipotle_df[chipotle_df['item_name'].str.contains('Burrito')]
# Out:
#       order_id  quantity         item_name  \
# 7            4         1     Steak Burrito
# 9            5         1     Steak Burrito
# 16           8         1   Chicken Burrito
# 17           9         1   Chicken Burrito
# 21          11         1  Barbacoa Burrito
# ...        ...       ...               ...
# 4608      1829         1    Veggie Burrito
# 4610      1830         1     Steak Burrito
# 4611      1830         1    Veggie Burrito
# 4617      1833         1     Steak Burrito
# 4618      1833         1     Steak Burrito
#
#                                      choice_description item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 16    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 17    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 21    [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...     $8.99
# ...

# %% [markdown]
# # Q6 'item_name'값이 Steak Salad 또는 Bowl인 데이터를 호출해주세요.- 난이도-중

# %%
chipotle_df[(chipotle_df['item_name'] == 'Steak Salad') | (chipotle_df['item_name'] == 'Bowl')]
# Out:
#       order_id  quantity    item_name  \
# 445        193         3         Bowl
# 664        276         1  Steak Salad
# 673        279         1         Bowl
# 752        311         1  Steak Salad
# 893        369         1  Steak Salad
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 664   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40
# 752   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 893   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...     $8.99
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69

# %% [markdown]
# # Q7. 전체 데이터의 결측값의 개수를 구해주세요.

# %%
chipotle_df.isna().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64
